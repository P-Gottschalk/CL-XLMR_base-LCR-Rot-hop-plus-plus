# %% [markdown]
# ###**Notebook Setup**

# %% [markdown]
# **Mount Prep**

# %%
from google.colab import drive
drive.mount("/content/drive/")

# %% [markdown]
# **Package Installation:**

# %%
! pip install matplotlib
! pip install torch
! pip install transformers
! pip install datasets
! pip install rdflib
! pip install tqdm
! pip install requests
! pip install hyperopt
! pip install scikit-learn

# %% [markdown]
# **GitHub Cloning:** 90-day access token is used

# %%
! rm -r CL-XLMR_base-LCR-Rot-hop-plus-plus #Remove GitHub whilst in session

# %%
# !git clone https://github.com/SmartStevie02/CL-XLMR_base-LCR-Rot-hop-plus-plus.git

# %% [markdown]
# ### **XLMR-LCR-Rot-hop++:**
# LCR-Rot-hop++ model, using various embedders, trained on the English dataset.

# %% [markdown]
# **Hyperparameter Optimisation:** since this optimisation is carried out using English training data, this is carried out in a seperate file and used to test on all languages.

# %% [markdown]
# **Model Training:** since this training is carried out using English training data, this is carried out in a seperate file and used to test on all languages.

# %% [markdown]
# **Model Validation:** validates the models using French language test data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "mBERT" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_English_LCR_hops2_dropout0-4_acc0-7898936170212766_mBERT.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-base" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_English_LCR_hops8_dropout0-30000000000000004_acc0-8218085106382979_xlm-roberta-base.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-large" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_English_LCR_hops2_dropout0-5_acc0-776595744680851_xlm-roberta-large.pt"

# %% [markdown]
# ### **XLMR-LCR-Rot-hop-XX++:**
# LCR-Rot-hop++ model, using various embedders, trained on the French dataset.

# %% [markdown]
# **Hyperparameter Optimisation:** carry out hyperparameter optimisation of the various language models using French language training data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "French" --model-type "mBERT"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "French" --model-type "xlm-roberta-base"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "French" --model-type "xlm-roberta-large"

# %% [markdown]
# **Model Training:** trains the actual models using French language training data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "mBERT" --year 2016 --phase "Train" --language "French" --hops 2 --learning 0.06 --dropout 0.6000000000000001 --momentum 0.85 --weight-decay 1e-05

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "xlm-roberta-base" --year 2016 --phase "Train" --language "French" --hops 2 --learning 0.08 --dropout 0.4 --momentum 0.95 --weight-decay 0.0001

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "xlm-roberta-large" --year 2016 --phase "Train" --language "French" --hops 2 --learning 0.06 --dropout 0.6000000000000001 --momentum 0.85 --weight-decay 1e-05

# %% [markdown]
# **Model Validation:** validates the models using French language test data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "mBERT" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_French_LCR_hops2_dropout0-6000000000000001_acc0-8248587570621468_mBERT.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-base" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_French_LCR_hops2_dropout0-4_acc0-844632768361582_xlm-roberta-base.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-large" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_French_LCR_hops2_dropout0-6000000000000001_acc0-8192090395480226_xlm-roberta-large.pt"

# %% [markdown]
# ### **XLMR-MLCR-Rot-hop++:**
# LCR-Rot-hop++ model, using various embedders, trained on a Multilingual dataset.

# %% [markdown]
# **Hyperparameter Optimisation:** since this optimisation is carried out using Multilingual training data, this is carried out in a seperate file and used to test on all languages.

# %% [markdown]
# **Model Training:** since this training is carried out using Multilingual training data, this is carried out in a seperate file and used to test on all languages.

# %% [markdown]
# **Model Validation:** validates the models using French language test data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "mBERT" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_Multilingual_LCR_hops2_dropout0-6000000000000001_acc0-7918486171761281_mBERT.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-base" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_Multilingual_LCR_hops2_dropout0-4_acc0-8486171761280932_xlm-roberta-base.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-large" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_Multilingual_LCR_hops2_dropout0-6000000000000001_acc0-8398835516739447_xlm-roberta-large.pt"

# %% [markdown]
# ### **XLMR-LCR-Rot-hop-ACS_FR++:**
# LCR-Rot-hop++ model, using various embedders, trained on a  dataset which is created using Aspect-Code Switching.

# %% [markdown]
# **Hyperparameter Optimisation:** carry out hyperparameter optimisation of the various language models using French language training data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "XACSforFrench" --model-type "mBERT"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "XACSforFrench" --model-type "xlm-roberta-base"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "XACSforFrench" --model-type "xlm-roberta-large"

# %% [markdown]
# **Model Training:** trains the actual models using ACS French language training data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "mBERT" --year 2016 --phase "Train" --language "XACSforFrench" --hops 2 --learning 0.06 --dropout 0.6000000000000001 --momentum 0.85 --weight-decay 1e-05

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "xlm-roberta-base" --year 2016 --phase "Train" --language "XACSforFrench" --hops 2 --learning 0.06 --dropout 0.6000000000000001 --momentum 0.85 --weight-decay  1e-05

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "xlm-roberta-large" --year 2016 --phase "Train" --language "XACSforFrench" --hops 2 --learning 0.06 --dropout 0.6000000000000001 --momentum 0.85 --weight-decay  1e-05

# %% [markdown]
# **Model Validation:** validates the models using French language test data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "mBERT" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_XACSforFrench_LCR_hops2_dropout0-6000000000000001_acc0-9077868852459017_mBERT.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-base" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_XACSforFrench_LCR_hops2_dropout0-6000000000000001_acc0-8913934426229508_xlm-roberta-base.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-large" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_XACSforFrench_LCR_hops2_dropout0-6000000000000001_acc0-8415300546448088_xlm-roberta-large.pt"

# %% [markdown]
# ### **CLS-XLMR-LCR-Rot-hop++:**
# LCR-Rot-hop++ model, using various embedders, trained on the English dataset, using sentiment-level contrastive learning.

# %% [markdown]
# **Hyperparameter Optimisation:** since this optimisation is carried out using English training data, this is carried out in a seperate file and used to test on all languages.

# %% [markdown]
# **Model Training:** since this training is carried out using English training data, this is carried out in a seperate file and used to test on all languages.

# %% [markdown]
# **Model Validation:** validates the models using French language test data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "mBERT" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_English_LCR_hops2_dropout0-6000000000000001_acc0-8377659574468085_mBERT_CL_Sen.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-base" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_English_LCR_hops2_dropout0-6000000000000001_acc0-8537234042553191_xlm-roberta-base_CL_Sen.pt"

# %% [markdown]
# ### **CLR-XLMR-LCR-Rot-hop++:**
# LCR-Rot-hop++ model, using various embedders, trained on the English dataset, using representation-level contrastive learning.

# %% [markdown]
# **Hyperparameter Optimisation:** since this optimisation is carried out using English training data, this is carried out in a seperate file and used to test on all languages.

# %% [markdown]
# **Model Training:** since this training is carried out using English training data, this is carried out in a seperate file and used to test on all languages.

# %% [markdown]
# **Model Validation:** validates the models using French language test data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "mBERT" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_English_LCR_hops2_dropout0-4_acc0-8351063829787234_mBERT_CL_Rep.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-base" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_English_LCR_hops2_dropout0-4_acc0-848404255319149_xlm-roberta-base_CL_Rep.pt"

# %% [markdown]
# ### **CLS-XLMR-LCR-Rot-hop-XX++:**
# LCR-Rot-hop++ model, using various embedders, trained on the French dataset, using sentiment-level contrastive learning.

# %% [markdown]
# **Hyperparameter Optimisation:** carry out hyperparameter optimisation of the various language models using French language training data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "French" --model-type "mBERT" --contrastive-learning "Sen"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "French" --model-type "xlm-roberta-base" --contrastive-learning "Sen"

# %% [markdown]
# **Model Training:** trains the actual models using French language training data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "mBERT" --year 2016 --phase "Train" --language "French" --hops 2 --learning 0.06 --dropout 0.6000000000000001 --momentum 0.85 --weight-decay 1e-05 --contrastive-learning "Sen" --beta 0.5

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "xlm-roberta-base" --year 2016 --phase "Train" --language "French" --hops 2 --learning 0.06 --dropout 0.6000000000000001 --momentum 0.85 --weight-decay 1e-05 --contrastive-learning "Sen" --beta 0.5

# %% [markdown]
# **Model Validation:** validates the models using French language test data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "mBERT" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_French_LCR_hops2_dropout0-6000000000000001_acc0-827683615819209_mBERT_CL_Sen.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-base" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_French_LCR_hops2_dropout0-6000000000000001_acc0-8502824858757062_xlm-roberta-base_CL_Sen.pt"

# %% [markdown]
# ### **CLR-XLMR-LCR-Rot-hop-XX++:**
# LCR-Rot-hop++ model, using various embedders, trained on the French dataset, using representation-level contrastive learning.

# %% [markdown]
# **Hyperparameter Optimisation:** carry out hyperparameter optimisation of the various language models using French language training data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "French" --model-type "mBERT" --contrastive-learning "Rep"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "French" --model-type "xlm-roberta-base" --contrastive-learning "Rep"

# %% [markdown]
# **Model Training:** trains the actual models using French language training data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "mBERT" --year 2016 --phase "Train" --language "French" --hops 2 --learning 0.06 --dropout 0.6000000000000001 --momentum 0.85 --weight-decay 1e-05 --contrastive-learning "Rep" --beta 0.3

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "xlm-roberta-base" --year 2016 --phase "Train" --language "French" --hops 2 --learning 0.06 --dropout 0.6000000000000001 --momentum 0.85 --weight-decay 1e-05 --contrastive-learning "Rep" --beta 0.3

# %% [markdown]
# **Model Validation:** validates the models using French language test data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "mBERT" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_French_LCR_hops2_dropout0-6000000000000001_acc0-8163841807909604_mBERT_CL_Rep.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-base" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_French_LCR_hops2_dropout0-6000000000000001_acc0-8361581920903954_xlm-roberta-base_CL_Rep.pt"

# %% [markdown]
# ### **CLS-XLMR-MLCR-Rot-hop++:**
# LCR-Rot-hop++ model, using various embedders, trained on the Multilingual dataset, using sentiment-level contrastive learning.

# %% [markdown]
# **Hyperparameter Optimisation:** since this optimisation is carried out using Multilingual training data, this is carried out in a seperate file and used to test on all languages.

# %% [markdown]
# **Model Training:** since this training is carried out using Multilingual training data, this is carried out in a seperate file and used to test on all languages.

# %% [markdown]
# **Model Validation:** validates the models using French language test data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "mBERT" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_Multilingual_LCR_hops2_dropout0-6000000000000001_acc0-7983988355167394_mBERT_CL_Sen.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-base" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_Multilingual_LCR_hops2_dropout0-6000000000000001_acc0-8522561863173217_xlm-roberta-base_CL_Sen.pt"

# %% [markdown]
# ### **CLR-XLMR-MLCR-Rot-hop++:**
# LCR-Rot-hop++ model, using various embedders, trained on the Multilingual dataset, using representation-level contrastive learning.

# %% [markdown]
# **Hyperparameter Optimisation:** since this optimisation is carried out using Multilingual training data, this is carried out in a seperate file and used to test on all languages.

# %% [markdown]
# **Model Training:** since this training is carried out using Multilingual training data, this is carried out in a seperate file and used to test on all languages.

# %% [markdown]
# **Model Validation:** validates the models using French language test data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "mBERT" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_Multilingual_LCR_hops2_dropout0-6000000000000001_acc0-7809315866084425_mBERT_CL_Rep.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-base" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_Multilingual_LCR_hops2_dropout0-6000000000000001_acc0-8427947598253275_xlm-roberta-base_CL_Rep.pt"

# %% [markdown]
# ### **CLS-XLMR-LCR-Rot-hop-ACS_FR++:**
# LCR-Rot-hop++ model, using various embedders, trained on the French ACS dataset, using sentiment-level contrastive learning.

# %% [markdown]
# **Hyperparameter Optimisation:** carry out hyperparameter optimisation of the various language models using French ACS language training data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "XACSforFrench" --model-type "mBERT" --contrastive-learning "Sen"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "XACSforFrench" --model-type "xlm-roberta-base" --contrastive-learning "Sen"

# %% [markdown]
# **Model Training:** trains the actual models using French ACS language training data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "mBERT" --year 2016 --phase "Train" --language "XACSforFrench" --hops 2 --learning 0.06 --dropout  0.6000000000000001 --momentum 0.85 --weight-decay 1e-05 --contrastive-learning "Sen" --beta 0.4

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "xlm-roberta-base" --year 2016 --phase "Train" --language "XACSforFrench" --hops 2 --learning 0.06 --dropout  0.6000000000000001 --momentum 0.85 --weight-decay 1e-05 --contrastive-learning "Sen" --beta 0.4

# %% [markdown]
# **Model Validation:** validates the models using French language test data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "mBERT" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_XACSforFrench_LCR_hops2_dropout0-6000000000000001_acc0-9255464480874317_mBERT_CL_Sen.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-base" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_XACSforFrench_LCR_hops2_dropout0-6000000000000001_acc0-894808743169399_xlm-roberta-base_CL_Sen.pt"

# %% [markdown]
# ### **CLR-XLMR-LCR-Rot-hop-ACS_FR++:**
# LCR-Rot-hop++ model, using various embedders, trained on the French ACS dataset, using representation-level contrastive learning.

# %% [markdown]
# **Hyperparameter Optimisation:** carry out hyperparameter optimisation of the various language models using French ACS language training data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "XACSforFrench" --model-type "mBERT" --contrastive-learning "Rep"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_hyperparam.py --year 2016 --phase "Train" --language "XACSforFrench" --model-type "xlm-roberta-base" --contrastive-learning "Rep"

# %% [markdown]
# **Model Training:** trains the actual models using French ACS language training data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "mBERT" --year 2016 --phase "Train" --language "XACSforFrench" --hops 2 --learning 0.06 --dropout  0.6000000000000001 --momentum 0.85 --weight-decay 1e-05 --contrastive-learning "Rep" --beta 0.5

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_train.py --model-type "xlm-roberta-base" --year 2016 --phase "Train" --language "XACSforFrench" --hops 2 --learning 0.06 --dropout  0.6000000000000001 --momentum 0.85 --weight-decay 1e-05 --contrastive-learning "Rep" --beta 0.5

# %% [markdown]
# **Model Validation:** validates the models using French language test data.

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "mBERT" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_XACSforFrench_LCR_hops2_dropout0-6000000000000001_acc0-9023224043715847_mBERT_CL_Rep.pt"

# %%
! python /content/CL-XLMR_base-LCR-Rot-hop-plus-plus/main_validate.py --language "French" --model-type "xlm-roberta-base" --model "/content/drive/MyDrive/Thesis_Data/data/models/2016_XACSforFrench_LCR_hops2_dropout0-6000000000000001_acc0-8784153005464481_xlm-roberta-base_CL_Rep.pt"
